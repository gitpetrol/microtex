# %% [markdown]
# # Ising 2D model with Kawasaki kinetics
#
# This exmaple shows Ising 2D model with Kawasaki dynamics (kinetics) simulationg the coarsening in binary solid solution.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

from microtex.models import Ising_Lattice_Model_2D, display_multiple_images
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6560/2272189377.py in <module>
#       6 from matplotlib import animation
#       7
# ----> 8 from symplex.models import Ising_Lattice_Model_2D, display_multiple_images
#
# c:\users\dlanda\projects\personal\thesis-prf-bsc\code\src\symplex\models\__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from symplex.models.ising_lattice import Ising_Lattice_Model_2D, display_multiple_images
#       4 from symplex.models.cahn_hilliard import Cahn_Hilliard_Model_2D
#       5
#
# c:\users\dlanda\projects\personal\thesis-prf-bsc\code\src\symplex\models\ising_lattice.py in <module>
#       1 from overrides import overrides
#       2
# ----> 3 from symplex.models import Model
#       4
#       5 import warnings
#
# ...

# %%
ising = Ising_2D(N = 200, temp = 0.4, kinetics = 'kawasaki', temp_point = 88, temp_range = (1, 5), equistep = 10, calcstep = None)

# %%
data = {i: ising.simulate(i) for i in range(100)}

# %%
g
ii = dict( list(data.items())[:2] + list(data.items())[0::17] + list(data.items())[-2:])
print(len(ii))

# sub = dict(list(] + list(data.items())[q1:q1+2] + list(data.items())[q2:q2+2]  + list(data.items())[q4:q4+2] +  list(data.items())[q4:q4+2] + list(data.items())[-2:])
# Out:
# 9

# %%
plt.rcParams['figure.figsize'] = (20,20)
display_multiple_images(ii, 3, 3)
